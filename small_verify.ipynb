# %%
from Sample_verify_small import Sample_small
a=0.8
b=0.2
way="map_tanh"
NN=100000
start = 0.1 #初始噪声方差
step = 0.1 #噪声方差变化步长
num_elements = 50 #噪声方差向量值数量
ss=Sample_small(a,b,way,NN,start,step,num_elements)
ss.Plot_T_noise() #噪声温度对应和kl散度计算图
# Out:
# map_tanh

# %%
noise=0.1
ss.Plot_noise(noise) #给定噪声下的Log（P）和能量图

# %%
noise=1
ss.Plot_noise(noise) #给定噪声下的Log（P）和能量图

# %%
from Sample_verify_small import Sample_small
a=0.8
b=0.2
noise=0.1
way="map_clip"
NN=100000
start = 0.1 #初始噪声方差
step = 0.01 #噪声方差变化步长
num_elements = 10 #噪声方差向量值数量
ss=Sample_small(a,b,way,NN,start,step,num_elements)
ss.Plot_T_noise() #噪声温度对应和kl散度计算图
ss.Plot_noise(noise) #给定噪声下的Log（P）和能量图
# Out:
# map_clip

# %%
noise=1
ss.Plot_noise(noise) #给定噪声下的Log（P）和能量图

# %%
from Sample_verify_small import Sample_small
a=0.8
b=0.2
way="map_pol"
NN=100000
start = 0.1 #初始噪声方差
step = 0.01 #噪声方差变化步长
num_elements = 10 #噪声方差向量值数量
ss=Sample_small(a,b,way,NN,start,step,num_elements)
ss.Plot_T_noise() #噪声温度对应和kl散度计算图
# Out:
# map_pol

# %%
noise=0.1
ss.Plot_noise(noise) #给定噪声下的Log（P）和能量图

# %%
noise=1
ss.Plot_noise(noise) #给定噪声下的Log（P）和能量图
